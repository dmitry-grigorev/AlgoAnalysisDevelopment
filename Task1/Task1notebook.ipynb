# %%
import numpy as np
import timeit
from plotnine import *
from task1module.task1module import *

# %%
np.random.seed(42)

# %% [markdown]
# # Experimental time complexity analysis
# ### Part $I$

# %%
v = np.random.exponential(1, 2000)

# %%
plot_algo_complexity_info(sum_of_elements, lambda x: x)+scale_y_continuous(limits = (0, 0.5))
# Out:
# c:\users\acer\pycharmprojects\computationalworkshop\venv\lib\site-packages\plotnine\layer.py:412: PlotnineWarning: geom_point : Removed 2 rows containing missing values.
# <ggplot: (132288115309)>

# %%
plot_algo_complexity_info(prod_of_elements, lambda x: x)+scale_y_continuous(limits = (0, 0.5))
# Out:
# c:\users\acer\pycharmprojects\computationalworkshop\venv\lib\site-packages\plotnine\layer.py:412: PlotnineWarning: geom_point : Removed 5 rows containing missing values.
# <ggplot: (132286913202)>

# %%
plot_algo_complexity_info(cacl_polynom_direct, lambda x: x, args = [1.5])+scale_y_continuous(limits = (0, 0.5))
# Out:
# <ipython-input-3-a163345953db>:24: RuntimeWarning: overflow encountered in double_scalars
# c:\users\acer\pycharmprojects\computationalworkshop\venv\lib\site-packages\plotnine\layer.py:412: PlotnineWarning: geom_point : Removed 7 rows containing missing values.
# c:\users\acer\pycharmprojects\computationalworkshop\venv\lib\site-packages\plotnine\geoms\geom_path.py:75: PlotnineWarning: geom_path: Removed 15 rows containing missing values.
# <ggplot: (132283998461)>

# %%
plot_algo_complexity_info(calc_polynom_horner, lambda x: x, args = [1.5])+scale_y_continuous(limits = (0, 0.5))
# Out:
# <ipython-input-3-a163345953db>:31: RuntimeWarning: overflow encountered in double_scalars
# c:\users\acer\pycharmprojects\computationalworkshop\venv\lib\site-packages\plotnine\layer.py:412: PlotnineWarning: geom_point : Removed 17 rows containing missing values.
# <ggplot: (132286909949)>
