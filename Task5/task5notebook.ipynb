# %%
from task5module.task5module import *
import numpy as np
import scipy as sp
import networkx as nx
import matplotlib.pyplot as plt

# %%
n = 100
m = 200
n1, m1 = 30, 50
n2, m2 = 20, 50
n3, m3 = n - n1 - n2, m - m1 - m2

np.random.seed(429)
Madj1, Madj2, Madj3 = generate_from_nm(n1, m1), generate_from_nm(n2,m2), generate_from_nm(n3, m3)
Madj = sp.linalg.block_diag(Madj1, Madj2, Madj3)

# %%
g = nx.from_numpy_matrix(Madj)

# %%
plt.figure(figsize=(4, 4))
nx.draw(g, node_size = 30)

# %%
Ladj = adj_mat_to_adj_list(Madj.tolist())
for i in range(10):
    print((i,Ladj[i]))
# Out:
# (0, [3, 6, 12, 20])
# (1, [4, 14, 15])
# (2, [9, 12, 19, 28])
# (3, [0, 6, 10, 20])
# (4, [1, 22, 27])
# (5, [])
# (6, [0, 3, 10, 15, 18, 20, 22])
# (7, [8, 21, 27])
# (8, [7, 13, 15])
# (9, [2, 10, 13, 18, 23])

# %%
bfs_adj(2, Ladj, vert_to_find=45)
# Out:
# No paths were found

# %%
bfs_adj(30, Ladj, 45)
# Out:
# [45, 36, 39, 30]

# %%
Ladj[30], Ladj[39], Ladj[36], Ladj[45]
# Out:
# ([39, 40, 46, 47],
#  [30, 36, 38, 41, 42],
#  [39, 42, 45, 46, 47, 49],
#  [36, 38, 43, 48])

# %%
components = find_components(Ladj)
max(components)+1
# Out:
# 8

# %%
#G = nx.path_graph(10)
pos = nx.kamada_kawai_layout(g)
nx.draw(g, pos = pos)
